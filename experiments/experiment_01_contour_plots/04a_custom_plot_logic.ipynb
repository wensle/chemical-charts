# %%
import os

import numpy as np
from dotenv import load_dotenv
from plotly.figure_factory._ternary_contour import (
    _compute_grid,
    _contour_trace,
    _prepare_barycentric_coord,
    _ternary_layout,
)
from plotly.graph_objs import graph_objs as go
from pycalphad import Database, calculate

from chemical_charts.config import DOTENV_PATH

# %%
load_dotenv(DOTENV_PATH)
# Out:
# True

# %% [markdown]
# In this notebook I explore a more low level approach for creating a ternary contour line plot. This approach is more flexible and allows for more customization. It is dependent on private functions in the `plotly.figure_factory._ternary_contour` module. Essentially I am reimplementing the logic in the `create_ternary_contour` factory function in the aforementioned module.

# %% [markdown]
# ## Setup (Do not include in class)

# %%
db_fname = "Al-Cu-Y.tdb"
db_path = os.path.join(os.getenv("TDB_DIR", ""), db_fname)
db_al_cu_y = Database(db_path)

# %%
comps = ['AL', 'CU', 'Y', 'VA']

# %%
c = calculate(db_al_cu_y, comps, 'FCC_A1', output='HM_MIX', T=830, P=101325, pdens=5000)

# %%
xs = c.X.values[0, 0, 0, :, 0]  # 1D array of Al compositions
ys = c.X.values[0, 0, 0, :, 1]  # 1D array of Cu compositions
zs = c.HM_MIX.values[0, 0, 0, :]  # 1D array of mixing enthalpies at these compositions

# %% [markdown]
# ## Parameters the class needs to be initialized with

# %%
colorscale = "Bluered"
linecolor = "black"
coloring = "lines"
coordinates, values = np.array([xs, ys, 1 - xs - ys]), zs
showscale = False
ncontours = 5
pole_labels = ["Al", "Cu", "Y"]
width = 500
height = 500
title = "Al-Cu-Y"

# %% [markdown]
# ## Logic to create the plot

# %%
barycentric_coordinates = _prepare_barycentric_coord(coordinates)
v_min, v_max = values.min(), values.max()

# %%
interp_mode="ilr"
grid_z, gr_x, gr_y = _compute_grid(barycentric_coordinates, values, interp_mode=interp_mode)

# %%
contour_trace, discrete_cm = _contour_trace(
    gr_x,
    gr_y,
    grid_z,
    ncontours=ncontours,
    colorscale=colorscale,
    linecolor=linecolor,
    interp_mode=interp_mode,
    coloring=coloring,
    v_min=v_min,
    v_max=v_max,
)

# %% [markdown]
# I can store the contour trace array somewhere, so that we can use it later to use as a prompt (maybe?) for Segment Anything Model. We can calculate the midpoint (is that even possible?) of the contour and use that as a prompt.

# %%
type(contour_trace[3]["a"])
# Out:
# numpy.ndarray

# %%
layout = dict(
    title=title,
    width=width,
    height=height,
    ternary=dict(
        sum=1,
        aaxis=dict(
            title=dict(text=pole_labels[0]), min=0.00, linewidth=2, ticks="outside", showgrid=False
        ),
        baxis=dict(
            title=dict(text=pole_labels[1]), min=0.00, linewidth=2, ticks="outside", showgrid=False
        ),
        caxis=dict(
            title=dict(text=pole_labels[2]), min=0.00, linewidth=2, ticks="outside", showgrid=False
        ),
        bgcolor="rgba(0,0,0,0)",
    ),
    showlegend=False,
)

# %%
contour_trace[0].update(
    dict(
        a=[1, 0, 0, 1],
        b=[0, 1, 0, 0],
        c=[0, 0, 1, 0],
        line=dict(color="black", width=4, shape="linear"),
    )
)

# %% [markdown]
# ## Return value

# %%
go.Figure(data=contour_trace, layout=layout)
# Out:
# <div>                            <div id="ace6d218-9315-4b7a-aac4-4ded7f0c5919" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ace6d218-9315-4b7a-aac4-4ded7f0c5919")) {                    Plotly.newPlot(                        "ace6d218-9315-4b7a-aac4-4ded7f0c5919",                        [{"a":[1,0,0,1],"b":[0,1,0,0],"c":[0,0,1,0],"fillcolor":"rgb(0,0,255)","hoverinfo":"skip","line":{"color":"black","shape":"linear","width":4},"mode":"lines","name":"-14800.130","showlegend":true,"type":"scatterternary"},{"a":[0.7840536838878056,0.7245382428425263,0.6558205059123843,0.5798997603578717,0.4999999999999902,0.44238353111342943,0.420100239642109,0.34417949408759907,0.2754617571574584,0.2159463161121812,0.19364960586827595,0.16633753081655928,0.16518715450440782,0.1262895790549168,0.09478739597319491,0.0705090956252292,0.06619301488427179,0.05209144932737403,0.03828650388225413,0.03512549384213545,0.0280318671516961,0.020465378938219137,0.01853389762788441,0.014909941389328359,0.010845859477081126,0.009753609146438441,0.007880683850330162,0.0057214757170902745,0.005126231578831021,0.004151387969270334,0.003010859071369507,0.0026924630910468623,0.0021829857714531194,0.0015823852808016954,0.0014138893676768874,0.0011468368765837518,0.0008310725150934422,0.0007425202268385789,0.0006021967266639965,0.0004363253693084495,0.00038974625307484163,0.0003161277976296129,0.00022903429655064082,0.00020451033828522717,0.0001659311530268424,0.0001202119908016242,0.00010731099239024224,8.708877388049205e-05,6.309175362748549e-05,5.630858193049197e-05,4.5706729760850896e-05,3.311201570636917e-05,2.9544284665305688e-05,2.3987753764060814e-05,1.7377706297569404e-05,1.5500593809435356e-05,1.2589095630617468e-05,9.120025217940436e-06,8.132128608665966e-06,6.606890828781031e-06,4.786278014659454e-06,4.266237272769997e-06,3.4673564819226163e-06,2.5118801219519475e-06,2.238070601340956e-06,1.8196975473047631e-06,1.3182550007578552e-06,1.1740682508741619e-06,9.549916740114566e-07,6.918304922891645e-07,6.158943986002459e-07,5.01186982438747e-07,3.630779229444699e-07,3.2308362581386846e-07,2.630267300064557e-07,1.9054603548852282e-07,1.694812948494936e-07,1.3803840740568228e-07,9.999998999999926e-08,8.890557876563331e-08,7.244359075942374e-08,5.248074327074776e-08,4.663789062823708e-08,3.801893818661585e-08,2.7542286274803896e-08,2.446547307994283e-08,1.9952622751581263e-08,1.4454397498529476e-08,1.2834392464473465e-08,1.0471285370861001e-08,7.58577569274776e-09,6.732961089197712e-09,5.495408708376617e-09,3.981071689685965e-09,3.5322226268458354e-09,2.884031494808924e-09,2.0892961264888434e-09,1.853118813515894e-09,1.5135612461453208e-09,1.09647819494091e-09,9.722405634063334e-10,7.943282340933128e-10,5.754399370060172e-10,5.10107269350958e-10,4.168693832965487e-10,3.01995171948997e-10,2.676508459076166e-10,2.1877616234708913e-10,1.5848931922099088e-10,1.4044202819778872e-10,1.1481536213650464e-10,8.317637710334736e-11,7.368066931370941e-11,6.025595860380457e-11,4.365158322211078e-11,3.86014165990556e-11,3.162277660068326e-11,2.8019713458016367e-11,2.29086765271525e-11,1.6595869074100025e-11,1.4705235061407138e-11,1.2022644346029476e-11,8.709635899484834e-12,7.718114403722824e-12,6.309573444762034e-12,4.570881896127777e-12,4.0511997219235e-12,3.311311214814886e-12,2.3988329190136974e-12,2.1266284904514e-12,1.7378008287463355e-12,1.258925411792566e-12,1.116445601201265e-12,9.120108393550654e-13,6.606934480071518e-13,5.861705979965775e-13,4.786300923224005e-13,3.467368504524066e-13,3.07789446926686e-13,2.511886431508901e-13,1.8197008586096295e-13,1.6163281199927954e-13,1.3182567385562133e-13,9.549925860213376e-14,8.488960607792301e-14,6.91830970918876e-14,5.011872336272398e-14,4.4589438405142524e-14,3.6307805477008345e-14,2 ...

# %%
contour_trace[0].update(
    dict(
        a=[1, 0, 0, 1],
        b=[0, 1, 0, 0],
        c=[0, 0, 1, 0],
        line=dict(color="black", width=3, shape="linear"),
    )
)
